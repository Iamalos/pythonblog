# %% [raw]
# ---
# title: New Post
# date: 2024-10-27
# description: A nice new post
# categories: [nonsence, code]
# ---

# %% [markdown]
# ## A nice heading
#
# Here is some lovely text and an equation.
#
# $$ a^2 + b^2 = c^2 $$
#
# Here's a list.
#
# - a link to an [external website](https://quarto.org).
# - a link to [another post in this blog](/posts/welcome/index.qmd).

# %% [markdown]
# ## Another heading
#
# Is this better or worse now? Let's check!

# %%
print('Hello, Quarto!')
# Out:
# Hello, Quarto!

# %%
#| fig-cap: This is my lovely line plot
#| fig-alt: A line plot extending to the right

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10)
y = 2*x + 1
plt.plot(x,y);
